# %%
import requests
from bs4 import BeautifulSoup
#Creating Header

headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36\", \"(KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36",
    "Referer": "https://www.google.com/search?q=brazil+journal&oq=Brazil+journal&aqs=chrome.0.0i512l10.656j0j1&sourceid=chrome&ie=UTF-8",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7"
}

# %%
#URL, Request and bs4 parser

URL = "https://braziljournal.com/"

r = requests.get(URL, headers=headers)

soup = BeautifulSoup(r.content, "html.parser")
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Brazil Journal - Criado por Geraldo Samor
#   </title>
#   <!-- bootstrap datalayer -->
#   <!-- Optimized with WP Meteor v3.2.0 - https://wordpress.org/plugins/wp-meteor/ -->
#   <script data-wpmeteor-nooptimize="true">
#    var _wpmeteor={"rdelay":2000,"preload":true,"v":"3.2.0","rest_url":"https:\/\/braziljournal.com\/wp-json\/"};(()=>{try{new MutationObserver(function(){}),new PerformanceObserver(function(){}),Object.assign({},{}),document.fonts.ready.then(function(){})}catch{t="wpmeteordisable=1",i=document.location.href,i.match(/[?&]wpmeteordisable/)||(o="",i.indexOf("?")==-1?i.indexOf("#")==-1?o=i+"?"+t:o=i.replace("#","?"+t+"#"):i.indexOf("#")==-1?o=i+"&"+t:o=i.replace("#","&"+t+"#"),document.location.href=o)}var t,i,o;})();
#   </script>
# ...

# %%
#Main headlines

URL = "https://braziljournal.com/"

r = requests.get(URL, headers=headers)

soup = BeautifulSoup(r.content, "html.parser")

headlines = soup.find_all("h2", class_="boxarticle-infos-title")

# Procurando por elementos filhos nas manchetes
for headline in headlines:
    headlines_href = headline.find("a")['href']
    headlines_text = headline.find("a").text
    # Formatando o texto
    headlines_text = headlines_text.strip()
    headlines_text = headlines_text.replace("  ", "")
    headlines_text = headlines_text.replace("BREAKING:", "")
    headlines_text = headlines_text.replace("EXCLUSIVO:", "")
    # Verificando se o texto não está vazio e não começa com espaços em branco antes de imprimir
    if headlines_text and not headlines_text.startswith(' '):
        print(headlines_text, ":", headlines_href)
# Out:
# MEMÓRIA: Alysson Paolinelli, o pai do Cerrado que se revoltava com a fome : https://braziljournal.com/memoria-alysson-paolinelli-o-pai-do-cerrado-que-se-revoltava-com-a-fome/
# Oferta da Vamos sai a R$ 11/ação; Simpar vende, família Simões compra R$ 260 mi : https://braziljournal.com/oferta-da-vamos-sai-a-r-11-acao-simpar-vende-familia-simoes-compra-r-260-mi/
# A fantástica história da Pismo, a fintech brasileira que a Visa comprou por US$ 1 bi : https://braziljournal.com/a-fantastica-historia-da-pismo-a-fintech-brasileira-que-a-visa-comprou-por-us-1-bi/
# GPA: Bilionário colombiano oferece R$ 4 bi pelo Exito : https://braziljournal.com/gpa-bilionario-colombiano-oferece-r-4-bi-pelo-exito/
# Hubs de coworking: a aposta das empresas para complementar o trabalho híbrido : https://braziljournal.com/brands/hubs-de-coworking-a-aposta-das-empresas-para-complementar-o-trabalho-hibrido/
# ...

# %%
#headlinesEconomy for economy

URL = "https://braziljournal.com/category/economia/"

r = requests.get(URL, headers=headers)

soup = BeautifulSoup(r.content, "html.parser")

headlinesEconomy = soup.find_all("h2", class_="boxarticle-infos-title")

for headline in headlinesEconomy:
    headlinesEconomy_href = headline.find("a")['href']
    headlinesEconomy_text = headline.find("a").text
    #Formating text and printing
    headlinesEconomy_text = headlinesEconomy_text.strip()
    headlinesEconomy_text = headlinesEconomy_text.replace("BREAKING:", "")
    headlinesEconomy_text = headlinesEconomy_text.replace("EXCLUSIVO:", "")
    headlinesEconomy_text = headlinesEconomy_text.replace("  ", "")
    if headlinesEconomy_text and not headlinesEconomy_text.lstrip().isspace():
        print(headlinesEconomy_text, ":", headlinesEconomy_href)
# Out:
# Oferta da Vamos sai a R$ 11/ação; Simpar vende, família Simões compra R$ 260 mi : https://braziljournal.com/oferta-da-vamos-sai-a-r-11-acao-simpar-vende-familia-simoes-compra-r-260-mi/
# Uma mulher sozinha.Um ponto de ônibus deserto.E a publicidade achou um propósito : https://braziljournal.com/uma-mulher-sozinha-um-ponto-de-onibus-deserto-e-a-publicidade-achou-um-proposito/
# MEMÓRIA: Alysson Paolinelli, o pai do Cerrado que se revoltava com a fome : https://braziljournal.com/memoria-alysson-paolinelli-o-pai-do-cerrado-que-se-revoltava-com-a-fome/
# Quanto mais o Ocidente brigar com a China, melhor para o Brasil, diz fundador da Gavekal : https://braziljournal.com/quanto-mais-o-ocidente-brigar-com-a-china-melhor-para-o-brasil-diz-fundador-da-gavekal/
# OPINIÃO: O novo Plano Diretor deveria deixar SP construir mais, não menos : https://braziljournal.com/opiniao-o-novo-plano-diretor-deveria-deixar-sp-construir-mais-nao-menos/
# ...

# %%
#headlinesBusiness for business

URL = "https://braziljournal.com/category/negocios/"

r = requests.get(URL, headers=headers)

soup = BeautifulSoup(r.content, "html.parser")

headlinesBusiness = soup.find_all("h2", class_="boxarticle-infos-title")

for headline in headlinesBusiness:
    headlinesBusiness_href = headline.find("a")['href']
    headlinesBusiness_text = headline.find("a").text
    #Formating text and printing
    headlinesBusiness_text = headlinesBusiness_text.strip()
    headlinesBusiness_text = headlinesBusiness_text.replace("BREAKING:", "")
    headlinesBusiness_text = headlinesBusiness_text.replace("EXCLUSIVO:", "")
    headlinesBusiness_text = headlinesBusiness_text.replace("  ", "")
    if headlinesBusiness_text and not headlinesBusiness_text.lstrip().isspace():
        print(headlinesBusiness_text, ":", headlinesBusiness_href)
# Out:
# Oferta da Vamos sai a R$ 11/ação; Simpar vende, família Simões compra R$ 260 mi : https://braziljournal.com/oferta-da-vamos-sai-a-r-11-acao-simpar-vende-familia-simoes-compra-r-260-mi/
# Uma mulher sozinha.Um ponto de ônibus deserto.E a publicidade achou um propósito : https://braziljournal.com/uma-mulher-sozinha-um-ponto-de-onibus-deserto-e-a-publicidade-achou-um-proposito/
# MEMÓRIA: Alysson Paolinelli, o pai do Cerrado que se revoltava com a fome : https://braziljournal.com/memoria-alysson-paolinelli-o-pai-do-cerrado-que-se-revoltava-com-a-fome/
# Quanto mais o Ocidente brigar com a China, melhor para o Brasil, diz fundador da Gavekal : https://braziljournal.com/quanto-mais-o-ocidente-brigar-com-a-china-melhor-para-o-brasil-diz-fundador-da-gavekal/
# OPINIÃO: O novo Plano Diretor deveria deixar SP construir mais, não menos : https://braziljournal.com/opiniao-o-novo-plano-diretor-deveria-deixar-sp-construir-mais-nao-menos/
# ...
